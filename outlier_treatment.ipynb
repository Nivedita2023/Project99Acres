# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                   society     sector  price  price_per_sqft  \
# 0          flat           pareena mi casa  sector 68   1.90          9227.0
# 1          flat     alpha corp gurgaonone  sector 84   2.28          8769.0
# 2          flat             m3m sierra 68  sector 68   1.10          8986.0
# 3         house  ireo victory valley4.0 ?  sector 67   8.00         22222.0
# 4          flat           kiran residency  sector 56   1.54          8324.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2059.0                   Carpet area: 2059 (191.29 sq.m.)        3
# 1  2600.0  Super Built up area 3434(319.03 sq.m.)Carpet a...        4
# 2  1224.0  Super Built up area 1224(113.71 sq.m.)Built Up...        2
# 3  3600.0                        Plot area 400(334.45 sq.m.)        6
# 4  1850.0  Super Built up area 2000(185.81 sq.m.)Built Up...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3      3+       1.0         NaN  Under Construction
# 1         4      3+       8.0  South-East      Relatively New
# 2         2       3       1.0  North-East      Relatively New
# 3         7      3+       3.0  North-East      Moderately Old
# 4         4      3+       5.0       South        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN       2059.0           0             1
# 1               3434.0            NaN       2600.0           0             1
# 2               1224.0         1150.0        830.0           0             0
# 3                  NaN          400.0          NaN           1             1
# 4               2000.0         1900.0       1850.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            49
# 1           0           0       0                0            61
# 2           0           0       0                1           127
# 3           1           1       0                1           151
# 4           0           0       0                0            98

# %%
df.shape
# Out:
# (3679, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.displot(df['price'])

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the price column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.236188
#  std        4.064749
#  min        5.490000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 1046         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 2509         house                                        independent
# 2845         house                                     dlf city plots
# 947          house                                        independent
# 1604         house                              suncity township4.1 ?
# 327          house                             emaar the palm springs
# 1036         house                                        independent
# 3035         house                                 vipul tatvam villa
# 2388         house                                     dlf city plots
# 290          house                             luxury dlf city floors
# 3265         house                                        independent
# 1369         house                                 vipul tatvam villa
# 3479         house                                        independent
# 3355         house                                        independent
# 2095         house                                     dlf city plots
# 2718         house                                 emaar mgf marbella
# 906          house                                        independent
# 1984         house                                 vipul tatvam villa
# 3762         house                                        independent
# 1031         house                                        independent
#
Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 1046         1000.0          NaN           1             1           1
# 2509         1254.0          NaN           1             1           0
# 2845          505.0          NaN           1             1           0
# 947           400.0        350.0           1             1           1
# 1604         1000.0          NaN           1             1           1
# 327           400.0          NaN           1             1           0
# 1036         1000.0          NaN           1             1           1
# 3035         1000.0          NaN           0             1           0
# 2388          502.0          NaN           1             1           1
# 290           500.0          NaN           0             1           0
# 3265          500.0          NaN           0             1           0
# 1369          975.0          NaN           1             1           1
# 3479          800.0          NaN           1             1           0
# 3355          500.0          NaN           1             1           1
# 2095          502.0          NaN           1             1           0
# 2718            NaN       6000.0           0             1           1
# 906           502.0          NaN           1             1           1
# 1984         7000.0          NaN           0             0           0
# 3762            NaN      11000.0           0             1           1
# 1031            NaN      10000.0           1             1           1
#
#       pooja room  others  furnishing_type  luxury_score
# 1046           1       0                2            74
# 2509           1       1                1            42
# 2845           1       1                1           138
# 947            1       0                1            72
# 1604           1       0                0             0
# 327            1       0                1           122
# 1036           1       0                1           145
# 3035           0       0                0            54
# 2388           1       0                1           153
# 290            0       0                1            31
# 3265           1       0                2            97
# 1369           1       0                1           110
# 3479           1       0                0           122
# 3355           1       0                1           103
# 2095           0       0                1           121
# 2718           1       0                1           110
# 906            1       0                1           120
# 1984           0       0                0            30
# 3762           1       0                1            60
# 1031           1       0                1            77

# %%
# On the basis of price col we can say that there are some genuine outliers but there are some data errors as well

# %% [markdown]
# #### Price_per_sqft

# %%
sns.displot(df['price_per_sqft'])

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52639.946328
#  std       61135.126407
#  min       24500.000000
#  25%       28241.250000
#  50%       33498.000000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29405.237288
# std      12416.410230
# min       2723.000000
# 25%      25575.500000
# 50%      29880.000000
# 75%      35694.750000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.displot(df['price_per_sqft'])

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 50000]
# Out:
#      property_type                       society           sector  price  \
# 105          house            emaar mgf marbella        sector 66  18.00
# 252          house            cloudnine cottages  sohna road road   5.50
# 263          house        emaar the palm springs        sector 54  14.00
# 327          house        emaar the palm springs        sector 54  24.00
# 527          house                   independent        sector 25  16.00
# 538           flat                unitech vistas        sector 70   9.00
# 947          house                   independent        sector 26  26.00
# 1066         house                           nul        sector 28  12.50
# 1651         house  project housing board colony        sector 31   8.00
# 1797         house                   independent        sector 26  14.75
# 2710         house                  malibu towne        sector 47   8.50
# 2845         house                dlf city plots        sector 26  26.00
# 3794         house           unitech escape3.8 ?        sector 50  10.80
#
#       price_per_sqft    area  \
# 105          55556.0  3240.0
# 252          55000.0  1000.0
# 263          62222.0  2250.0
# 327          66667.0  3600.0
# 527          59259.0  2700.0
# 538          57508.0  1565.0
# 947          82540.0  3150.0
# 1066         51440.0  2430.0
# 1651         63492.0  1260.0
# 1797         51864.0  2844.0
# 2710         53125.0  1600.0
# 2845         57206.0  4545.0
# 3794         60000.0  1800.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 105                         Plot area 360(301.01 sq.m.)        4         4
# 252                          Plot area 1000(92.9 sq.m.)        3         3
# 263                         Plot area 250(209.03 sq.m.)        4         5
# 327                          Plot area 400(37.16 sq.m.)        5         5
# 527   Plot area 350(292.64 sq.m.)Built Up area: 325 ...       16        16
# 538                  Built Up area: 1565 (145.39 sq.m.)        3         3
# 947   Plot area 402(336.12 sq.m.)Built Up area: 400 ...       16        16
# 1066                        Plot area 270(225.75 sq.m.)       16        17
# 1651                  Built Up area: 140 (117.06 sq.m.)        2         1
# 1797                        Plot area 316(264.22 sq.m.)       16        20
# 2710                 Built Up area: 1600 (148.64 sq.m.)       12        12
# 2845                        Plot area 505(422.24 sq.m.)        6         7
# 3794  Plot area 290(242.48 sq.m.)Built Up area: 250 ...        4         4
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 105       3+       3.0        East  Moderately Old                  NaN
# 252        0       1.0         NaN  Moderately Old                  NaN
# 263       3+       2.0       North    Old Property                  NaN
# 327        2       1.0  North-East    Old Property                  NaN
# 527       3+       4.0        West    New Property                  NaN
# 538        0       7.0         NaN       Undefined                  NaN
# 947       3+       4.0  North-West    New Property                  NaN
# 1066      3+       4.0       South  Relatively New                  NaN
# 1651       0       1.0         NaN       Undefined                  NaN
# 1797      3+       4.0        East    New Property                  NaN
# 2710      3+       4.0       North    New Property                  NaN
# 2845      3+       2.0  North-East    New Property                  NaN
# 3794       3       2.0       North  Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 105           360.0          NaN           1             1           0
# 252          1000.0          NaN           0             0           0
# 263           250.0          NaN           1             1           0
# 327           400.0          NaN           1             1           0
# 527           325.0        300.0           1             1           1
# 538          1565.0          NaN           0             0           0
# 947           400.0        350.0           1             1           1
# 1066          270.0          NaN           1             1           0
# 1651          140.0          NaN           0             0           0
# 1797          316.0          NaN           1             1           1
# 2710         1600.0          NaN           0             0           0
# 2845          505.0          NaN           1             1           0
# 3794          250.0        200.0           1             1           1
#
#       pooja room  others  furnishing_type  luxury_score
# 105            1       0                2            75
# 252            0       0                0             0
# 263            0       0                1           160
# 327            1       0                1           122
# 527            1       0                1            72
# 538            0       0                0             0
# 947            1       0                1            72
# 1066           1       1                2           137
# 1651           0       0                0             0
# 1797           1       0                0           153
# 2710           0       0                1            99
# 2845           1       1                1           138
# 3794           1       0                1           103

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# #### Area

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3648.000000
# mean       2947.294408
# std       23205.026544
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 523           flat  signature global solera 2  sector 107   0.51
# 1092          flat          hcbs sports ville  sohna road   0.35
# 1283          flat      signature the roselia   sector 95   0.45
# 2226          flat            ramsons kshitij   sector 95   0.31
# 3461         house                independent   sector 50   5.00
#
#       price_per_sqft      area                           areaWithType  \
# 523              9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 1092             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 1283             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 2226             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 3461           232.0  215517.0             Plot area 2(1011.71 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 523         2         2       1       3.0       North    New Property
# 1092        2         2       2       8.0         NaN  Relatively New
# 1283        2         2       2       2.0  South-West    New Property
# 2226        2         2       1       1.0  North-East  Relatively New
# 3461        6         5      3+       2.0         NaN    New Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 523                   NaN            NaN     514396.0           0
# 1092                  NaN       737147.0          NaN           0
# 1283                  NaN            NaN     569243.0           0
# 2226                  NaN            NaN     607936.0           1
# 3461                  NaN            2.0          NaN           1
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 523              0           0           0       0                0
# 1092             0           0           0       0                2
# 1283             0           0           0       0                0
# 2226             0           0           0       1                0
# 3461             1           0           1       1                0
#
#       luxury_score
# 523             44
# 1092            44
# 1283            76
# 2226            65
# 3461             0

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area', ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 3762         house                independent        sector 26  18.40
# 2985         house  ganpati heights apartment        sector 13   1.25
# 506           flat                 rof ananda        sector 95   0.38
# 2080          flat                 rof ananda        sector 95   0.38
# 2705         house      dlf city plot phase 4        sector 28  13.00
# 1736          flat              pyramid elite        sector 86   0.46
# 1311          flat                 rof ananda        sector 95   0.33
# 1157          flat      signature the serenas       sohna road   0.28
# 3411         house                independent        sector 25   7.30
# 2978          flat            ramsons kshitij        sector 95   0.24
# 1275          flat                 rof ananda        sector 95   0.21
# 3046         house                independent        sector 57   6.25
# 1606         house                independent        sector 43   5.50
# 1973          flat                 godrej air        sector 85   2.50
moderately Old                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 3762            NaN     11000.00           0             1           1
# 2985          115.0          NaN           0             0           0
# 506             NaN     64529.00           1             0           0
# 2080            NaN     64412.00           0             0           0
# 2705            NaN      7250.00           0             0           0
# 1736            NaN     58141.00           0             0           0
# 1311            NaN     54917.00           0             0           0
# 1157            NaN     48811.00           1             0           0
# 3411         5800.0      5200.00           0             1           1
# 2978            NaN     45966.00           0             0           0
# 1275            NaN     34401.00           0             0           0
# 3046         2660.0      2500.00           0             1           0
# 1606         2850.0      2250.00           1             1           0
# 1973            NaN     18122.00           1             0           0
# 1065         2160.0      1720.00           0             1           0
# 80           1500.0          NaN           0             0           0
# 831             NaN      1175.11           0             0           0
# 2509         1254.0          NaN           1             1           0
# 473             NaN     11000.00           0             1           0
# 2186         3500.0          NaN           1             1           0
#
#       pooja room  others  furnishing_type  luxury_score
# 3762           1       0                1            60
# 2985           0       1                0             7
# 506            0       0                0            15
# 2080           0       0                0            51
# 2705           0       0                0             0
# 1736           0       0                0            15
# 1311           0       0                0            37
# 1157           0       0                0            37
# 3411           0       0                1           109
# 2978           0       1                0            33
# 1275           0       0                0            68
# 3046           0       0                1            61
# 1606           1       1                1           123
# 1973           1       1                1            44
# 1065           0       0                0           160
# 80             0       1                0             0
# 831            0       0                0            55
# 2509           1       1                1            42
# 473            0       0                0            60
# 2186           1       1                0            49

# %%
df.drop(index=[3762, 2985, 506, 2080, 2705, 1736, 1311, 1157, 3411, 2978, 1275, 3046, 1606, 1973, 1065, 80, 831, 2509, 473, 2186], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3623.000000
# mean      1940.160640
# std       1183.679661
# min        145.000000
# 25%       1260.000000
# 50%       1745.000000
# 75%       2322.500000
# max      10000.000000
# Name: area, dtype: float64

# %% [markdown]
# #### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3623.000000
# mean        3.324593
# std         1.818692
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 1269         house                  independent   sector 54   5.00
# 555          house                  independent   sector 43   4.50
# 1044         house                  independent  sector 17a   3.87
# 1506         house                  independent  sector 17a   3.93
# 556          house                private house   sector 55   7.05
# 399          house                  independent   sector 54   5.50
0          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 1269           0       0                2            49
# 555            0       0                2            22
# 1044           0       0                0            68
# 1506           1       0                0            74
# 556            0       1                2            57
# 399            0       0                2            70
# 290            0       0                1            31
# 1947           1       1                0            41
# 441            1       0                1             0
# 2388           1       0                1           153
# 1682           1       0                1            49
# 3044           1       0                1            49
# 2283           0       0                1            20
# 2548           0       0                2            15
# 2695           1       1                0             0
# 59             0       0                2             7
# 532            1       0                2            91
# 2216           1       0                2           122
# 2350           1       0                1            72
# 17             1       1                1            49
# 2955           1       0                1            40
# 2645           0       0                1           114
# 1749           1       0                1            32
# 3260           1       0                1            42
# 3457           0       0                2            50
# 3558           1       0                1            43
# 3645           1       1                2            49
# 1888           1       0                1            49
# 1490           1       1                1           106
# 1711           1       0                2            44
# 1536           0       1                1            40
# 1513           0       1                0            49
# 53             1       0                1           144
# 1473           1       0                1            72
# 1438           0       0                1            73
# 1153           0       0                0            32
# 1053           0       0                1            21
# 838            1       0                1            49
# 765            1       1                1            49
# 603            0       1                2            20
# 422            0       0                1           105
# 403            0       0                0            15
# 134            0       0                1            57
# 3793           0       0                1            71
# 1244           0       1                2            28

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3578, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3578.000000
# mean        3.194243
# std         1.376548
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# #### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type                    society     sector  price  \
# 3043         house  adani brahma samsara4.2 ?  sector 60  18.02
# 1969         house                independent  sector 24  11.00
# 2419         house                independent  sector 39   7.00
#
#       price_per_sqft    area  \
# 3043         28200.0  6390.0
# 1969         28902.0  3806.0
# 2419         10000.0  7000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 3043                 Built Up area: 6390 (593.65 sq.m.)        9        12
# 1969  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8        11
# 2419  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10        11
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 3043      3+       3.0  North-East  Relatively New                  NaN
# 1969      3+       3.0        East    Old Property                  NaN
# 2419      3+       4.0  South-East  Relatively New                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 3043         6390.0          NaN           0             1           0
# 1969         5000.0          NaN           1             1           0
# 2419         7000.0          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 3043           0       0                1           146
# 1969           1       1                1            39
# 2419           1       0                1            38

# %%
df.head()
# Out:
#   property_type                   society     sector  price  price_per_sqft  \
# 0          flat           pareena mi casa  sector 68   1.90          9227.0
# 1          flat     alpha corp gurgaonone  sector 84   2.28          8769.0
# 2          flat             m3m sierra 68  sector 68   1.10          8986.0
# 3         house  ireo victory valley4.0 ?  sector 67   8.00         22222.0
# 4          flat           kiran residency  sector 56   1.54          8324.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2059.0                   Carpet area: 2059 (191.29 sq.m.)        3
# 1  2600.0  Super Built up area 3434(319.03 sq.m.)Carpet a...        4
# 2  1224.0  Super Built up area 1224(113.71 sq.m.)Built Up...        2
# 3  3600.0                        Plot area 400(334.45 sq.m.)        6
# 4  1850.0  Super Built up area 2000(185.81 sq.m.)Built Up...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3      3+       1.0         NaN  Under Construction
# 1         4      3+       8.0  South-East      Relatively New
# 2         2       3       1.0  North-East      Relatively New
# 3         7      3+       3.0  North-East      Moderately Old
# 4         4      3+       5.0       South        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN       2059.0           0             1
# 1               3434.0            NaN       2600.0           0             1
# 2               1224.0         1150.0        830.0           0             0
# 3                  NaN          400.0          NaN           1             1
# 4               2000.0         1900.0       1850.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            49
# 1           0           0       0                0            61
# 2           0           0       0                1           127
# 3           1           1       0                1           151
# 4           0           0       0                0            98

# %% [markdown]
# #### **super built up area**

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1380          flat  bestech park view grand spa    sector 81    4.7
# 3429          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1380          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3429          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1380        4         4      3+      19.0       North  Relatively New
# 3429        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1380               6926.0            NaN          NaN           0
# 3429              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# 1380             1           0           0       0                1
# 3429             1           0           1       1                0
#
#       luxury_score
# 1380           140
# 3429            49

# %% [markdown]
# #### **built up area**

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %% [markdown]
# #### **carpet area**

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxury_score]
# Index: []

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
sns.boxplot(x=df['luxury_score'])
# Out:
# <Axes: xlabel='luxury_score'>

# %%
df.shape
# Out:
# (3578, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                   society     sector  price  price_per_sqft  \
# 0          flat           pareena mi casa  sector 68   1.90          9228.0
# 1          flat     alpha corp gurgaonone  sector 84   2.28          8769.0
# 2          flat             m3m sierra 68  sector 68   1.10          8987.0
# 3         house  ireo victory valley4.0 ?  sector 67   8.00         22222.0
# 4          flat           kiran residency  sector 56   1.54          8324.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2059.0                   Carpet area: 2059 (191.29 sq.m.)        3
# 1  2600.0  Super Built up area 3434(319.03 sq.m.)Carpet a...        4
# 2  1224.0  Super Built up area 1224(113.71 sq.m.)Built Up...        2
# 3  3600.0                        Plot area 400(334.45 sq.m.)        6
# 4  1850.0  Super Built up area 2000(185.81 sq.m.)Built Up...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3      3+       1.0         NaN  Under Construction
# 1         4      3+       8.0  South-East      Relatively New
# 2         2       3       1.0  North-East      Relatively New
# 3         7      3+       3.0  North-East      Moderately Old
# 4         4      3+       5.0       South        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN       2059.0           0             1
# 1               3434.0            NaN       2600.0           0             1
# 2               1224.0         1150.0        830.0           0             0
# 3                  NaN          400.0          NaN           1             1
# 4               2000.0         1900.0       1850.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0            49
# 1           0           0       0                0            61
# 2           0           0       0                1           127
# 3           1           1       0                1           151
# 4           0           0       0                0            98

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 165          house  sushant lok 1 builder floors   sector 43   13.0
# 307          house                   independent   sector 43    9.5
# 1697         house                   independent   sector 25   13.0
# 2068         house                   independent   sector 55    5.0
# 2095         house                dlf city plots   sector 26   19.0
# 3057         house                   independent   sector 28   12.0
# 3265         house                   independent   sector 26   20.0
# 3355         house                   independent   sector 26   19.0
# 3641         house                   independent  sector 105    9.9
#
#       price_per_sqft    area  \
# 165          48148.0  2700.0
# 307          42222.0  2250.0
# 1697         45710.0  2844.0
# 2068         44444.0  1125.0
# 2095         42054.0  4518.0
# 3057         42194.0  2844.0
# 3265         44444.0  4500.0
# 3355         42222.0  4500.0
# 3641         49500.0  2000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 165                         Plot area 300(250.84 sq.m.)        3         3
# 307   Plot area 302(252.51 sq.m.)Built Up area: 300 ...        5         5
# 1697                        Plot area 316(264.22 sq.m.)        6         8
# 2068  Plot area 125(104.52 sq.m.)Built Up area: 115 ...        9         9
# 2095                        Plot area 502(419.74 sq.m.)        6         6
# 3057                        Plot area 316(264.22 sq.m.)        4         5
# 3265                        Plot area 500(418.06 sq.m.)        5         7
# 3355                        Plot area 500(418.06 sq.m.)        6         8
# 3641  Built Up area: 2000 (185.81 sq.m.)Carpet area:...        2         2
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 165       3+       4.0       North    New Property                  NaN
# 307       3+       2.0  North-East  Relatively New                  NaN
# 1697      3+       NaN         NaN  Relatively New                  NaN
# 2068      3+       5.0        East    New Property                  NaN
# 2095       3       2.0        East  Relatively New                  NaN
# 3057      3+       4.0        East  Relatively New                  NaN
# 3265      3+       3.0        West  Relatively New                  NaN
# 3355      3+       3.0        East  Moderately Old                  NaN
# 3641       2       3.0       North       Undefined                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 165           300.0          NaN           0             0           0
# 307           300.0        250.0           0             1           0
# 1697          316.0          NaN           1             1           1
# 2068          115.0        100.0           0             0           0
# 2095          502.0          NaN           1             1           0
# 3057          316.0          NaN           0             1           1
# 3265          500.0          NaN           0             1           0
# 3355          500.0          NaN           1             1           1
# 3641         2000.0       1800.0           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 165            1       0                1             7
# 307            1       0                1            88
# 1697           1       0                2             0
# 2068           0       1                1            44
# 2095           0       0                1           121
# 3057           1       0                1            60
# 3265           1       0                2            97
# 3355           1       0                1           103
# 3641           0       0                0             0

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# 251.60000000000002

# %%
df[(df['area']/df['bedRoom'])<183].sample(5)
# Out:
#      property_type      society     sector  price  price_per_sqft    area  \
# 2482         house  independent   sector 4   0.50         10482.0   477.0
# 672          house  independent  sector 13   1.50         11538.0  1300.0
# 499          house    rk excelo  sector 12   0.60         13333.0   450.0
# 193          house  independent  sector 41   4.25         26235.0  1620.0
# 3242         house   jacob pura  sector 12   0.35          9722.0   360.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 2482                    Built Up area: 53 (44.31 sq.m.)        5         3
# 672                        Plot area 1300(120.77 sq.m.)       10         7
# 499   Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...        5         3
# 193                          Plot area 180(150.5 sq.m.)       10         9
# 3242                   Built Up area: 360 (33.45 sq.m.)        2         1
#
#      balcony  floorNum facing   agePossession  super_built_up_area  \
# 2482       0       1.0    NaN       Undefined                  NaN
# 672        3       4.0   East  Moderately Old                  NaN
# 499        2       3.0  North  Moderately Old                  NaN
# 193       3+       4.0  North  Moderately Old                  NaN
# 3242       0       NaN    NaN    Old Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 2482           53.0          NaN           0             0           0
# 672          1300.0          NaN           0             0           0
# 499            30.0         15.0           0             0           0
# 193           180.0          NaN           1             1           0
# 3242          360.0          NaN           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score
# 2482           0       0                0             0
# 672            0       0                0             0
# 499            0       1                0             0
# 193            0       0                1            36
# 3242           0       0                0             0

# %%
sns.lmplot(data=df, x='area', y='bedRoom')

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio'] < 250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     33
# 5     28
# 6     17
# 4     17
# 9     15
# 8     12
# 7      8
# 10     7
# Name: count, dtype: int64

# %%
df = df[df['area_room_ratio'] > 100]

# %%
outliers_df = df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\Mr\AppData\Local\Temp\ipykernel_452\3450078040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)]
# Out:
#      property_type               society            sector  price  \
# 101          house           independent          sector 2   0.98
# 259          house           independent  sector 3 phase 2   0.85
# 1133         house           independent         sector 17   0.32
# 1305         house           independent           manesar   0.80
# 1588         house           independent        sector 105   1.10
# 1812         house           independent         sector 11   3.50
# 2185         house              shivpuri          sector 7   2.80
# 2328         house           independent          sector 7   1.16
# 3144         house  bhim nagar, sector 6          sector 6   0.85
# 3321         house           independent         sector 12   2.50
# 3336         house           independent  sector 3 phase 2   1.10
# 3691         house           independent           manesar   1.10
# 3799         house           independent         sector 12   0.65
#
#       price_per_sqft    area  \
# 101           9074.0  1080.0
# 259           9444.0   900.0
# 1133          5664.0   565.0
# 1305          6667.0  1200.0
# 1588         12222.0   900.0
# 1812         15556.0  2250.0
# 2185         12444.0  2250.0
# 2328         11717.0   990.0
# 3144         14096.0   603.0
# 3321         13889.0  1800.0
# 3336         10000.0  1100.0
# 3691          6173.0  1782.0
# 3799          6500.0  1000.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 101                     Carpet area: 120 (100.34 sq.m.)        9         4
# 259                      Carpet area: 900 (83.61 sq.m.)        5         3
# 1133                   Built Up area: 565 (52.49 sq.m.)        5         1
# 1305                       Plot area 1200(111.48 sq.m.)        8         8
# 1588                     Carpet area: 900 (83.61 sq.m.)        6         4
# 1812                 Built Up area: 2250 (209.03 sq.m.)       10         1
# 2185                       Plot area 2250(209.03 sq.m.)       10         7
# 2328                     Carpet area: 110 (91.97 sq.m.)        5         4
# 3144                           Plot area 67(6.22 sq.m.)        5         2
# 3321                       Plot area 1800(167.23 sq.m.)        9         5
# 3336  Built Up area: 1100 (102.19 sq.m.)Carpet area:...        5         4
# 3691                       Plot area 1782(165.55 sq.m.)        8         8
# 3799                     Carpet area: 1000 (92.9 sq.m.)        6         2
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 101        3       1.0       South       Undefined                  NaN
# 259        3       1.0         NaN       Undefined                  NaN
# 1133       0       1.0         NaN       Undefined                  NaN
# 1305       2       1.0         NaN  Relatively New                  NaN
# 1588       1       1.0  South-West       Undefined                  NaN
# 1812       0       1.0         NaN    New Property                  NaN
# 2185       3       1.0         NaN    Old Property                  NaN
# 2328       2       1.0  North-East       Undefined                  NaN
# 3144       2       1.0         NaN    Old Property                  NaN
# 3321       2       1.0  South-East    Old Property                  NaN
# 3336       2       1.0        East       Undefined                  NaN
# 3691       0       1.0         NaN    New Property                  NaN
# 3799       3       1.0         NaN       Undefined                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 101             NaN        120.0           0             0           0
# 259             NaN        900.0           0             0           0
# 1133          565.0          NaN           0             0           0
# 1305         1200.0          NaN           0             0           0
# 1588            NaN        900.0           0             0           0
# 1812         2250.0          NaN           0             0           0
# 2185         2250.0          NaN           1             1           0
# 2328            NaN        110.0           0             0           0
# 3144           67.0          NaN           0             0           0
# 3321         1800.0          NaN           0             0           0
# 3336         1100.0        900.0           0             0           0
# 3691         1782.0          NaN           0             0           0
# 3799            NaN       1000.0           0             0           0
#
#       pooja room  others  furnishing_type  luxury_score  area_room_ratio
# 101            0       0                0             0       120.000000
# 259            0       0                0             0       180.000000
# 1133           0       0                0             0       113.000000
# 1305           0       0                0             0       150.000000
# 1588           0       0                0             0       150.000000
# 1812           0       0                0             0       225.000000
# 2185           1       1                1             0       225.000000
# 2328           0       0                0             0       198.000000
# 3144           1       0                0            29       120.600000
# 3321           1       0                0             8       200.000000
# 3336           0       0                0             0       220.000000
# 3691           0       0                0             0       222.750000
# 3799           0       0                0             0       166.666667

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)].shape
# Out:
# (13, 24)

# %%
df.shape
# Out:
# (3558, 24)

# %%
df = df[~((df['area_room_ratio'] < 250) & (df['bedRoom'] > 4))]

# %%
sns.lmplot(data=df, x='area', y='bedRoom')

# %%
df.shape
# Out:
# (3545, 24)

# %%
df.head()
# Out:
#   property_type                   society     sector  price  price_per_sqft  \
# 0          flat           pareena mi casa  sector 68   1.90          9228.0
# 1          flat     alpha corp gurgaonone  sector 84   2.28          8769.0
# 2          flat             m3m sierra 68  sector 68   1.10          8987.0
# 3         house  ireo victory valley4.0 ?  sector 67   8.00         22222.0
# 4          flat           kiran residency  sector 56   1.54          8324.0
#
#      area                                       areaWithType  bedRoom  \
# 0  2059.0                   Carpet area: 2059 (191.29 sq.m.)        3
# 1  2600.0  Super Built up area 3434(319.03 sq.m.)Carpet a...        4
# 2  1224.0  Super Built up area 1224(113.71 sq.m.)Built Up...        2
# 3  3600.0                        Plot area 400(334.45 sq.m.)        6
# 4  1850.0  Super Built up area 2000(185.81 sq.m.)Built Up...        3
#
#    bathroom balcony  floorNum      facing       agePossession  \
# 0         3      3+       1.0         NaN  Under Construction
# 1         4      3+       8.0  South-East      Relatively New
# 2         2       3       1.0  North-East      Relatively New
# 3         7      3+       3.0  North-East      Moderately Old
# 4         4      3+       5.0       South        Old Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                  NaN            NaN       2059.0           0             1
# 1               3434.0            NaN       2600.0           0             1
# 2               1224.0         1150.0        830.0           0             0
# 3                  NaN          400.0          NaN           1             1
# 4               2000.0         1900.0       1850.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score  \
# 0           0           0       0                0            49
# 1           0           0       0                0            61
# 2           0           0       0                1           127
# 3           1           1       0                1           151
# 4           0           0       0                0            98
#
#    area_room_ratio
# 0       686.333333
# 1       650.000000
# 2       612.000000
# 3       600.000000
# 4       616.666667

# %%
df.to_csv('gurgaon_properties_outlier_treated.csv',index=False)
